# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")

# %%
movies.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
credits = pd.read_csv("tmdb_5000_credits.csv")

# %%
credits.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
movies = movies.drop(["budget","homepage","original_language","popularity","production_companies","keywords","overview","production_countries","release_date","revenue","runtime","spoken_languages","status","original_title"], axis=1)

# %%
credits = credits.drop(["cast","crew"], axis =1)

# %%
movies.rename(columns={'id':'movie_id'}, inplace= True)
movies.head()
# Out:
#                                               genres  ...  vote_count
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  ...       11800
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...  ...        4500
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  ...        4466
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...  ...        9106
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  ...        2124
#
# [5 rows x 6 columns]

# %%
DF = movies.merge(credits, on= ["movie_id","title"])

# %%
DF = DF.drop(["genres","vote_count"], axis=1)

# %%
DF.head()
# Out:
#    movie_id  ... vote_average
# 0     19995  ...          7.2
# 1       285  ...          6.9
# 2    206647  ...          6.3
# 3     49026  ...          7.6
# 4     49529  ...          6.1
#
# [5 rows x 4 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(24,6))
ax = sns.countplot(x="vote_average", data= DF)

# %%
DF.duplicated().sum()
# Out:
# 0
